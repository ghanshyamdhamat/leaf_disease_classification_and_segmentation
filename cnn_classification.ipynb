# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob
import skimage as ski
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import pandas as pd
from sklearn.model_selection import KFold
from skimage import transform as ski_transform
from torchvision.transforms import ToTensor, Normalize, Compose, RandomRotation
from torchvision import models
import torchvision.transforms.functional as FT
from torcheval.metrics import functional as FM
from torchinfo import summary

# %%
transforms = Compose([
    ToTensor(),
    RandomRotation(10),
    Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
])

def joint_random_rotation(image, label, degrees):
    # Get a random angle from the range [-degrees, degrees]
    angle = RandomRotation.get_params([-degrees, degrees])
    
    # Rotate the image using bilinear interpolation
    image = FT.rotate(image, angle, interpolation=Image.BILINEAR)
    
    # Rotate the label using nearest neighbor to avoid interpolating label values
    label = FT.rotate(label, angle, interpolation=Image.NEAREST)

    return image, label

def joint_random_horizontal_flip(image, label):
    if torch.rand(1) < 0.5:
        image = FT.hflip(image)
        label = FT.hflip(label)
    return image, label

def joint_random_vertical_flip(image, label):
    if torch.rand(1) < 0.5:
        image = FT.vflip(image)
        label = FT.vflip(label)

    return image, label

def joint_random_crop(image, label, output_size):
    # Get the size of the image
    w, h = image.size

    # Get the target size
    th, tw = output_size

    # Randomly crop the image
    i = torch.randint(0, h - th + 1, (1,))
    j = torch.randint(0, w - tw + 1, (1,))
    image = FT.crop(image, i.item(), j.item(), th, tw)
    
    # Crop the label using the same parameters
    label = FT.crop(label, i.item(), j.item(), th, tw)

    return image, label

# %%
BATCH_SIZE = [16]
EPOCHS = 200
LEARNING_RATE = [0.0001]#,0.0001,0.00001]
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
RESIZE_DIM = (256, 256)
fold_number = [0,1,2,3,4]
repeats = 3
val_step = 1 # Every 3 epoch carry out validation
seed = 42
np.random.seed(seed)
torch.manual_seed(seed)

# %%
## Provide training path and test_path
train_path = r'/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/mlds_assignmet_2_ml_dl/Dataset/train'
test_path = r'/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/mlds_assignmet_2_ml_dl/Dataset/test'

train_csv_path = r'/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/mlds_assignmet_2_ml_dl/train.csv'
test_csv_path = r'/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/mlds_assignmet_2_ml_dl/test.csv'

# %%
"""
id : Name of the image
Binary prediction
    Healthy = 0
    Diseased = 1
segmentation prediction
    Probably the id of the diseased pixel
"""
train_csv_data = pd.read_csv(train_csv_path)
#Sort train_csv_data by id
train_csv_data = train_csv_data.sort_values(by='id')
train_csv_data.head(10)
# Out:
#           id  binary_pred                                  segmentation_pred
# 0      0.png            1  27797 2 28053 4 28063 2 28309 15 28565 19 2882...
# 1      1.png            1  3629 4 3883 8 4137 12 4390 17 4644 21 4898 25 ...
# 10    10.png            0                                            Healthy
# 100  100.png            1  19931 7 20187 10 20443 10 20699 10 20955 10 21...
# 101  101.png            1  6392 4 6645 7 6899 9 7150 15 7394 27 7645 32 7...
# 102  102.png            1  8475 1 8730 4 8986 5 9242 6 9498 7 9754 9 1001...
# 103  103.png            0                                            Healthy
# 104  104.png            0                                            Healthy
# 105  105.png            1  17528 1 17781 5 17846 1 18034 9 18102 2 18287 ...
# 106  106.png            1  23612 5 23866 9 24121 9 24377 6 29270 25 29524...

# %%
# class CNNclassificationmodel(nn.Module):
#     def __init__(self, num_classes, in_channels, out_channels):
#         super(CNNclassificationmodel,self).__init__()
#         self.num_classes = num_classes
#         self.in_channels = in_channels
#         self.out_channels = out_channels

#         #Current size: 224x224 if input is  256*256
#         self.conv1 = nn.Sequential(
#             nn.Conv2d(in_channels, 16, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(16),
#             nn.Dropout(p=0.1),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )

#         #Current size: 112x112  16*16 128*128
#         self.conv2 = nn.Sequential(
#             nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(32),
#             nn.Dropout(p=0.1),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )
  
#         # Current size: 56x56  8*8  64*64
#         self.conv3 = nn.Sequential(
#             nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(64),
#             nn.Dropout(p=0.1),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )

#         #Current size: 28x28 filter = 192 32*32
#         self.conv4 = nn.Sequential(
#             nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(128),
#             nn.Dropout(p=0.1),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )

#         # # #Current size: 14x14 filters = 128  16*16
#         self.conv5 = nn.Sequential(
#             nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
#             nn.BatchNorm2d(256),
#             nn.Dropout(p=0.1),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=2, stride=2)
#         )

#         # 8*8
#         self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
#         self.fc = nn.Sequential(
#             nn.Linear(256*1*1, 128, bias=True),
#             nn.ReLU(inplace=True),
#             nn.Dropout(p=0.3),
#             nn.Linear(128, 32, bias=True),
#             nn.ReLU(inplace=True),
#             nn.Dropout(p=0.3),
#             nn.Linear(32, 1)
#         )
        

#     def forward(self, x):
#         x1 = self.conv1(x)
#         # x2 = self.conv2(x1)
#         x3 = self.conv3(x2)
#         x4 = self.conv4(x3)
#         x5 = self.conv5(x4)
#         x6 = self.global_avg_pool(x5)
#         x7 = x6.reshape(x.size(0), -1)
#         x8 = self.fc(x7)
#         return x8

# %%
class CustomDataset(Dataset):
    def __init__(self, images, masks, labels, is_train= True, resize_dim = (224, 224)):
        self.resize_dim = resize_dim
        self.images = images
        self.is_train = is_train
        self.image_transform = Compose([
            ToTensor(),
            Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
        ])
        self.label_transform = ToTensor()
        if is_train:
            self.masks = masks
            self.labels = labels
        else:
            self.masks = None
            self.labels = labels

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if idx >= len(self.images):
            print('Reduce the index count as it is greater than the length of the dataset')
            return None
        if idx < 0:
            print('Index should be greater than or equal to 0')
            return None
        data = {}

        if self.is_train:
            data['image'] = Image.open(self.images[idx])
            data['mask'] = Image.open(self.masks[idx])
            data['class_label'] = self.labels.iloc[idx, 1]
            data['id'] = self.images[idx].split('/')[-1]
            data['image'], data['mask'] = joint_random_rotation(data['image'], data['mask'], 10)
            data['image'], data['mask'] = joint_random_horizontal_flip(data['image'], data['mask'])
            data['image'], data['mask'] = joint_random_vertical_flip(data['image'], data['mask'])
            data['image'], data['mask'] = joint_random_crop(data['image'], data['mask'], self.resize_dim)
            data['image'] = data['image'].resize(self.resize_dim)
            data['mask'] = data['mask'].resize(self.resize_dim)
            data['class_label'] = torch.tensor(data['class_label']).float()
            if self.image_transform:
                data['image'] = self.image_transform(data['image']) 
                data['mask'] = self.label_transform(data['mask'])
            return data
        else:
            data['image'] = Image.open(self.images[idx])
            data['id'] = self.images[idx].split('/')[-1]
            if self.image_transform:
                data['image'] = self.image_transform(data['image'])
            return data

# %%
# Split the images in val and train from train_path
def create_k_fold_split(train_path, train_csv_path):
    # Create a KFold object
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    train_img_paths = glob(os.path.join(train_path, 'images', '*.png'))
    train_img_paths.sort()
    train_mask_paths = glob(os.path.join(train_path, 'masks', '*.png'))
    train_mask_paths.sort()
    train_labels = pd.read_csv(train_csv_path)
    train_labels = train_labels.sort_values(by='id')
    train_labels.index = range(len(train_labels))
    split = list(kf.split(train_img_paths))
    return split, train_img_paths, train_mask_paths, train_labels

# %%
def get_datasets(train_img_paths, train_mask_paths, train_labels, val_img_paths, val_mask_paths, val_labels):
    train_dataset = CustomDataset(train_img_paths, train_mask_paths, train_labels, is_train=True, resize_dim=RESIZE_DIM)
    val_dataset = CustomDataset(val_img_paths, val_mask_paths, val_labels, is_train=True, resize_dim=RESIZE_DIM)
    return train_dataset, val_dataset

def get_dataloader(train_dataset, val_dataset, batch_size):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    return train_loader, val_loader

def get_splitted_data(train_indices, val_indices):
    train = [train_img_paths[i] for i in train_indices]
    train_masks = [train_mask_paths[i] for i in train_indices]
    training_labels = train_labels.iloc[train_indices]
    val = [train_img_paths[i] for i in val_indices]
    val_masks = [train_mask_paths[i] for i in val_indices]
    val_labels = train_labels.iloc[val_indices]
    return train, train_masks, training_labels, val, val_masks, val_labels



split, train_img_paths, train_mask_paths, train_labels = create_k_fold_split(train_path, train_csv_path)

# %%
for repeat in range(1):
    for fold in fold_number:
        for lr in LEARNING_RATE:
            for batch in BATCH_SIZE:
                    weights = models.ResNet18_Weights
                    model = models.resnet18(weights=weights.IMAGENET1K_V1)
                    # num_ftrs = model.fc.in_features
                    model.fc = nn.Sequential(
                                nn.Linear(model.fc.in_features, 1)
                                    )
                    name = 'resnet18'
                    model = model.to(DEVICE)
                    # freeze all layers except the last one
                    for param in model.parameters():
                        param.requires_grad = False
                    for param in model.fc.parameters():
                        param.requires_grad = True
                    criterion = nn.BCEWithLogitsLoss(reduction='mean')
                    optimizer = optim.Adam(model.fc.parameters(), lr=lr, weight_decay=1e-5)
                    sum =summary (model, input_size=(batch, 3, RESIZE_DIM[0], RESIZE_DIM[1]), device=DEVICE)
                    train_indices, val_indices = split[fold]
                    with open(f'resnet18_model_summary_lr_{lr}_batch_{batch}.txt', 'w') as f:
                        f.write(str(sum))

                    train, train_masks, training_labels, val, val_masks, val_labels = get_splitted_data(train_indices, val_indices)
                    train_dataset, val_dataset = get_datasets(train, train_masks, training_labels, val, val_masks, val_labels)
                    train_loader, val_loader = get_dataloader(train_dataset, val_dataset, batch)      
                    best_model = None
                    best_val_loss = float('inf')
                    results = {
                        'train_loss': [],
                        'val_loss': [],
                        'train_accuracy': [],
                        'val_accuracy': [],
                        'val_precision': [],
                        'val_recall': [],
                        'val_f1_score': []
                    }
                    print(f'Training with learning rate: {lr}, batch size: {batch}, fold: {fold}, repeat: {repeat}')
                    for epoch in range(EPOCHS):
                        # Training Phase
                        model.train()
                        total_train_loss = 0
                        total_train_correct = 0
                        total_train_samples = 0
                        for data in train_loader:
                            image = data['image'].to(DEVICE)
                            label = data['class_label'].unsqueeze(1).float().to(DEVICE)
                            optimizer.zero_grad()
                            output = model(image)

                            loss = criterion(output, label)
                            loss.backward()
                            optimizer.step()

                            total_train_loss += loss.item() 
                            predicted = (torch.sigmoid(output) > 0.5).float()
                            total_train_correct += (predicted == label).float().sum().item()
                            total_train_samples += label.size(0)
                        # Compute average train loss and accuracy for the epoch
                        avg_train_loss = total_train_loss / len(train_loader)
                        train_accuracy = total_train_correct / total_train_samples
                        
                        results['train_loss'].append(avg_train_loss)
                        results['train_accuracy'].append(train_accuracy)
                        
                        # Validation Phase (every val_step epochs)
                        if epoch % val_step == 0:
                            model.eval()
                            total_val_loss = 0
                            tp = 0
                            fp = 0
                            fn = 0
                            tn = 0
                            with torch.no_grad():
                                for data in val_loader:
                                    image = data['image'].to(DEVICE)
                                    label = data['class_label'].unsqueeze(1).float().to(DEVICE)
                                    # Forward pass
                                    output = model(image)
                                    # Compute loss
                                    # print(f'validation output: {output}, val_label : {label}')
                                    loss = criterion(output, label)
                                    total_val_loss += loss.item()
                                    # Compute accuracy
                                    predicted = (torch.sigmoid(output) > 0.5).float()
                                    # print(f'predicted: {predicted}, val_label : {label}')
                                    tp += ((predicted == 1) & (label == 1)).sum().item()
                                    fp += ((predicted == 1) & (label == 0)).sum().item()
                                    fn += ((predicted == 0) & (label == 1)).sum().item()
                                    tn += ((predicted == 0) & (label == 0)).sum().item()
                                # Compute average validation loss and accuracy
                                avg_val_loss = total_val_loss / len(val_loader)
                                val_accuracy = (tp + tn) / (tp + fp + fn + tn)
                                val_precision = tp / (tp + fp + 1e-10)
                                val_recall = tp / (tp + fn + 1e-10)
                                val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall + 1e-10)
                                results['val_loss'].append(avg_val_loss)
                                results['val_accuracy'].append(val_accuracy)
                                results['val_recall'].append(val_recall)
                                results['val_f1_score'].append(val_f1_score)
                                results['val_precision'].append(val_precision)
                                # Save best model
                                if avg_val_loss < best_val_loss:
                                    best_val_loss = avg_val_loss
                                    best_model = model.state_dict()
                                    torch.save(best_model, f'classification_model/best_model_{name}_lr_{lr}_batch_{batch}_fold_{fold}_repeat_{repeat}.pth')
                                
                                #implement early stopping
                                if epoch > 50 and (avg_val_loss > np.mean(np.array(results['val_loss'][-20:]))):
                                    print(f"Early stopping at epoch {epoch+1} with validation loss {best_val_loss:.4f}")
                                    break
                                # Print epoch statistics
                                print(f'Epoch {epoch+1}:')
                                print(f'Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')
                                print(f'Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
                        # scheduler.step(avg_val_loss)           
                    # Save results to CSV
                    results_df = pd.DataFrame(results)
                    results_df.to_csv(f'class_results_{name}_lr_{lr}_batch_{batch}_fold_{fold}_repeat_{repeat+1}.csv', index=False)
                    print(f"Results saved for lr: {lr}, batch: {batch}, fold: {fold}, repeat: {repeat+1}")
# Out:
# Training with learning rate: 0.0001, batch size: 16, fold: 0, repeat: 0
# Epoch 1:
# Train Loss: 0.7129, Train Accuracy: 0.5502
# Validation Loss: 0.6442, Validation Accuracy: 0.6319
# Epoch 2:
# Train Loss: 0.6610, Train Accuracy: 0.6135
# Validation Loss: 0.5963, Validation Accuracy: 0.6978
# Epoch 3:
# Train Loss: 0.6122, Train Accuracy: 0.6616
# Validation Loss: 0.5491, Validation Accuracy: 0.7253
# Epoch 4:
# Train Loss: 0.5759, Train Accuracy: 0.7125
# Validation Loss: 0.5243, Validation Accuracy: 0.7912
# Epoch 5:
# Train Loss: 0.5401, Train Accuracy: 0.7414
# Validation Loss: 0.4879, Validation Accuracy: 0.7967
# Epoch 6:
# Train Loss: 0.5087, Train Accuracy: 0.7937
# Validation Loss: 0.4506, Validation Accuracy: 0.8462
# Epoch 7:
# Train Loss: 0.4867, Train Accuracy: 0.8116
# Validation Loss: 0.4387, Validation Accuracy: 0.8626
# Epoch 8:
# Train Loss: 0.4645, Train Accuracy: 0.8501
# Validation Loss: 0.4226, Validation Accuracy: 0.8956
# Epoch 9:
# Train Loss: 0.4355, Train Accuracy: 0.8638
# Validation Loss: 0.3788, Validation Accuracy: 0.8681
# Epoch 10:
# Train Loss: 0.4224, Train Accuracy: 0.8845
# Validation Loss: 0.3726, Validation Accuracy: 0.8956
# Epoch 11:
# Train Loss: 0.4084, Train Accuracy: 0.8638
# Validation Loss: 0.3588, Validation Accuracy: 0.9396
# Epoch 12:
# Train Loss: 0.3965, Train Accuracy: 0.8790
# Validation Loss: 0.3372, Validation Accuracy: 0.9231
# Epoch 13:
# Train Loss: 0.3795, Train Accuracy: 0.8996
# Validation Loss: 0.3447, Validation Accuracy: 0.9066
# Epoch 14:
# Train Loss: 0.3643, Train Accuracy: 0.9010
# Validation Loss: 0.3237, Validation Accuracy: 0.9396
# Epoch 15:
# Train Loss: 0.3581, Train Accuracy: 0.8968
# Validation Loss: 0.3172, Validation Accuracy: 0.9176
# Epoch 16:
# Train Loss: 0.3559, Train Accuracy: 0.8955
# Validation Loss: 0.2981, Validation Accuracy: 0.9231
# Epoch 17:
# Train Loss: 0.3435, Train Accuracy: 0.9078
# Validation Loss: 0.2871, Validation Accuracy: 0.9341
# Epoch 18:
# Train Loss: 0.3389, Train Accuracy: 0.9161
# Validation Loss: 0.2904, Validation Accuracy: 0.9396
# Epoch 19:
# Train Loss: 0.3282, Train Accuracy: 0.9216
# Validation Loss: 0.2814, Validation Accuracy: 0.9286
# Epoch 20:
# Train Loss: 0.3135, Train Accuracy: 0.9120
# Validation Loss: 0.2694, Validation Accuracy: 0.9286
# Epoch 21:
# Train Loss: 0.3220, Train Accuracy: 0.9065
# Validation Loss: 0.2739, Validation Accuracy: 0.9066
# Epoch 22:
# Train Loss: 0.3260, Train Accuracy: 0.8982
# Validation Loss: 0.2549, Validation Accuracy: 0.9451
# Epoch 23:
# Train Loss: 0.3086, Train Accuracy: 0.9092
# Validation Loss: 0.2537, Validation Accuracy: 0.9451
# Epoch 24:
# Train Loss: 0.3030, Train Accuracy: 0.9188
# Validation Loss: 0.2674, Validation Accuracy: 0.9341
# Epoch 25:
# Train Loss: 0.2920, Train Accuracy: 0.9037
# Validation Loss: 0.2418, Validation Accuracy: 0.9505
# Epoch 26:
# Train Loss: 0.2981, Train Accuracy: 0.9065
# Validation Loss: 0.2393, Validation Accuracy: 0.9560
# Epoch 27:
# Train Loss: 0.2814, Train Accuracy: 0.9175
# Validation Loss: 0.2462, Validation Accuracy: 0.9396
# Epoch 28:
# Train Loss: 0.2816, Train Accuracy: 0.9133
# Validation Loss: 0.2399, Validation Accuracy: 0.9451
# Epoch 29:
# Train Loss: 0.2720, Train Accuracy: 0.9271
# Validation Loss: 0.2410, Validation Accuracy: 0.9341
# Epoch 30:
# Train Loss: 0.2859, Train Accuracy: 0.9120
# Validation Loss: 0.2327, Validation Accuracy: 0.9396
# Epoch 31:
# Train Loss: 0.2802, Train Accuracy: 0.9106
# Validation Loss: 0.2223, Validation Accuracy: 0.9341
# Epoch 32:
# Train Loss: 0.2582, Train Accuracy: 0.9340
# Validation Loss: 0.2177, Validation Accuracy: 0.9451
# Epoch 33:
# Train Loss: 0.2485, Train Accuracy: 0.9354
# Validation Loss: 0.2174, Validation Accuracy: 0.9451
# Epoch 34:
# Train Loss: 0.2639, Train Accuracy: 0.9202
# Validation Loss: 0.2075, Validation Accuracy: 0.9341
# Epoch 35:
# Train Loss: 0.2631, Train Accuracy: 0.9257
# Validation Loss: 0.2074, Validation Accuracy: 0.9176
# Epoch 36:
# Train Loss: 0.2512, Train Accuracy: 0.9340
# Validation Loss: 0.2134, Validation Accuracy: 0.9560
# Epoch 37:
# Train Loss: 0.2549, Train Accuracy: 0.9257
# Validation Loss: 0.2030, Validation Accuracy: 0.9451
# Epoch 38:
# Train Loss: 0.2481, Train Accuracy: 0.9271
# Validation Loss: 0.2165, Validation Accuracy: 0.9176
# Epoch 39:
# Train Loss: 0.2489, Train Accuracy: 0.9243
# Validation Loss: 0.1944, Validation Accuracy: 0.9505
# Epoch 40:
# Train Loss: 0.2434, Train Accuracy: 0.9312
# Validation Loss: 0.2020, Validation Accuracy: 0.9505
# Epoch 41:
# Train Loss: 0.2385, Train Accuracy: 0.9298
# Validation Loss: 0.1924, Validation Accuracy: 0.9505
# Epoch 42:
# Train Loss: 0.2449, Train Accuracy: 0.9326
# Validation Loss: 0.1972, Validation Accuracy: 0.9505
# Epoch 43:
# Train Loss: 0.2359, Train Accuracy: 0.9340
# Validation Loss: 0.2093, Validation Accuracy: 0.9341
# Epoch 44:
# Train Loss: 0.2330, Train Accuracy: 0.9243
# Validation Loss: 0.1940, Validation Accuracy: 0.9451
# Epoch 45:
# Train Loss: 0.2509, Train Accuracy: 0.9120
# Validation Loss: 0.2004, Validation Accuracy: 0.9396
# Epoch 46:
# Train Loss: 0.2513, Train Accuracy: 0.9243
# Validation Loss: 0.1945, Validation Accuracy: 0.9451
# Epoch 47:
# Train Loss: 0.2328, Train Accuracy: 0.9367
# Validation Loss: 0.1906, Validation Accuracy: 0.9341
# Epoch 48:
# Train Loss: 0.2270, Train Accuracy: 0.9298
# Validation Loss: 0.1883, Validation Accuracy: 0.9505
# Epoch 49:
# Train Loss: 0.2211, Train Accuracy: 0.9271
# Validation Loss: 0.1860, Validation Accuracy: 0.9560
# Epoch 50:
# Train Loss: 0.2424, Train Accuracy: 0.9120
# Validation Loss: 0.1988, Validation Accuracy: 0.9396
# Epoch 51:
# Train Loss: 0.2204, Train Accuracy: 0.9285
# Validation Loss: 0.2012, Validation Accuracy: 0.9396
# Epoch 52:
# Train Loss: 0.2193, Train Accuracy: 0.9354
# Validation Loss: 0.1770, Validation Accuracy: 0.9505
# Epoch 53:
# Train Loss: 0.2166, Train Accuracy: 0.9367
# Validation Loss: 0.1816, Validation Accuracy: 0.9670
# Epoch 54:
# Train Loss: 0.2218, Train Accuracy: 0.9257
# Validation Loss: 0.1659, Validation Accuracy: 0.9725
# Epoch 55:
# Train Loss: 0.2380, Train Accuracy: 0.9285
# Validation Loss: 0.1813, Validation Accuracy: 0.9451
# Epoch 56:
# Train Loss: 0.2156, Train Accuracy: 0.9340
# Validation Loss: 0.1795, Validation Accuracy: 0.9341
# Epoch 57:
# Train Loss: 0.2077, Train Accuracy: 0.9285
# Validation Loss: 0.1815, Validation Accuracy: 0.9341
# Epoch 58:
# Train Loss: 0.2186, Train Accuracy: 0.9230
# Validation Loss: 0.1757, Validation Accuracy: 0.9396
# Epoch 59:
# Train Loss: 0.2282, Train Accuracy: 0.9271
# Validation Loss: 0.1793, Validation Accuracy: 0.9396
# Epoch 60:
# Train Loss: 0.2059, Train Accuracy: 0.9367
# Validation Loss: 0.1827, Validation Accuracy: 0.9341
# Epoch 61:
# Train Loss: 0.2025, Train Accuracy: 0.9354
# Validation Loss: 0.1698, Validation Accuracy: 0.9615
# Epoch 62:
# Train Loss: 0.2137, Train Accuracy: 0.9354
# Validation Loss: 0.1770, Validation Accuracy: 0.9396
# Epoch 63:
# Train Loss: 0.2148, Train Accuracy: 0.9271
# Validation Loss: 0.1593, Validation Accuracy: 0.9451
# Epoch 64:
# Train Loss: 0.2099, Train Accuracy: 0.9312
# Validation Loss: 0.1576, Validation Accuracy: 0.9560
# Epoch 65:
# Train Loss: 0.1903, Train Accuracy: 0.9381
# Validation Loss: 0.1720, Validation Accuracy: 0.9505
# Epoch 66:
# Train Loss: 0.2047, Train Accuracy: 0.9326
# Validation Loss: 0.1683, Validation Accuracy: 0.9451
# Epoch 67:
# Train Loss: 0.2029, Train Accuracy: 0.9395
# Validation Loss: 0.1598, Validation Accuracy: 0.9505
# Epoch 68:
# Train Loss: 0.2017, Train Accuracy: 0.9381
# Validation Loss: 0.1605, Validation Accuracy: 0.9560
# Early stopping at epoch 69 with validation loss 0.1576
# Results saved for lr: 0.0001, batch: 16, fold: 0, repeat: 1
# Training with learning rate: 0.0001, batch size: 16, fold: 1, repeat: 0
# Epoch 1:
# Train Loss: 0.6834, Train Accuracy: 0.5777
# Validation Loss: 0.6610, Validation Accuracy: 0.6209
# Epoch 2:
# Train Loss: 0.5966, Train Accuracy: 0.6878
# Validation Loss: 0.6276, Validation Accuracy: 0.6374
# Epoch 3:
# Train Loss: 0.5673, Train Accuracy: 0.7139
# Validation Loss: 0.6064, Validation Accuracy: 0.6648
# Epoch 4:
# Train Loss: 0.5367, Train Accuracy: 0.7744
# Validation Loss: 0.5746, Validation Accuracy: 0.7198
# Epoch 5:
# Train Loss: 0.5084, Train Accuracy: 0.7854
# Validation Loss: 0.5644, Validation Accuracy: 0.7143
# Epoch 6:
# Train Loss: 0.4811, Train Accuracy: 0.8157
# Validation Loss: 0.5466, Validation Accuracy: 0.7308
# Epoch 7:
# Train Loss: 0.4688, Train Accuracy: 0.8184
# Validation Loss: 0.5063, Validation Accuracy: 0.8132
# Epoch 8:
# Train Loss: 0.4374, Train Accuracy: 0.8680
# Validation Loss: 0.4999, Validation Accuracy: 0.7692
# Epoch 9:
# Train Loss: 0.4214, Train Accuracy: 0.8528
# Validation Loss: 0.4758, Validation Accuracy: 0.7802
# Epoch 10:
# Train Loss: 0.4090, Train Accuracy: 0.8707
# Validation Loss: 0.4557, Validation Accuracy: 0.8077
# Epoch 11:
# Train Loss: 0.4033, Train Accuracy: 0.8624
# Validation Loss: 0.4329, Validation Accuracy: 0.8132
# Epoch 12:
# Train Loss: 0.3813, Train Accuracy: 0.8872
# Validation Loss: 0.4385, Validation Accuracy: 0.8462
# Epoch 13:
# Train Loss: 0.3776, Train Accuracy: 0.8872
# Validation Loss: 0.4320, Validation Accuracy: 0.8462
# Epoch 14:
# Train Loss: 0.3608, Train Accuracy: 0.8845
# Validation Loss: 0.4197, Validation Accuracy: 0.8352
# Epoch 15:
# Train Loss: 0.3485, Train Accuracy: 0.8968
# Validation Loss: 0.4125, Validation Accuracy: 0.8132
# Epoch 16:
# Train Loss: 0.3353, Train Accuracy: 0.8913
# Validation Loss: 0.3947, Validation Accuracy: 0.8626
# Epoch 17:
# Train Loss: 0.3305, Train Accuracy: 0.9078
# Validation Loss: 0.3819, Validation Accuracy: 0.8736
# Epoch 18:
# Train Loss: 0.3242, Train Accuracy: 0.8982
# Validation Loss: 0.3793, Validation Accuracy: 0.8516
# Epoch 19:
# Train Loss: 0.3076, Train Accuracy: 0.9285
# Validation Loss: 0.3636, Validation Accuracy: 0.8846
# Epoch 20:
# Train Loss: 0.3055, Train Accuracy: 0.9147
# Validation Loss: 0.3613, Validation Accuracy: 0.8736
# Epoch 21:
# Train Loss: 0.2876, Train Accuracy: 0.9243
# Validation Loss: 0.3552, Validation Accuracy: 0.8846
# Epoch 22:
# Train Loss: 0.2961, Train Accuracy: 0.9120
# Validation Loss: 0.3696, Validation Accuracy: 0.8736
# Epoch 23:
# Train Loss: 0.3112, Train Accuracy: 0.9051
# Validation Loss: 0.3430, Validation Accuracy: 0.8791
# Epoch 24:
# Train Loss: 0.2792, Train Accuracy: 0.9133
# Validation Loss: 0.3372, Validation Accuracy: 0.8791
# Epoch 25:
# Train Loss: 0.2796, Train Accuracy: 0.9188
# Validation Loss: 0.3331, Validation Accuracy: 0.8956
# Epoch 26:
# Train Loss: 0.2722, Train Accuracy: 0.9243
# Validation Loss: 0.3486, Validation Accuracy: 0.8901
# Epoch 27:
# Train Loss: 0.2680, Train Accuracy: 0.9188
# Validation Loss: 0.3287, Validation Accuracy: 0.8571
# Epoch 28:
# Train Loss: 0.2783, Train Accuracy: 0.9051
# Validation Loss: 0.3306, Validation Accuracy: 0.9011
# Epoch 29:
# Train Loss: 0.2676, Train Accuracy: 0.9202
# Validation Loss: 0.3211, Validation Accuracy: 0.9066
# Epoch 30:
# Train Loss: 0.2563, Train Accuracy: 0.9312
# Validation Loss: 0.3097, Validation Accuracy: 0.8956
# Epoch 31:
# Train Loss: 0.2662, Train Accuracy: 0.9161
# Validation Loss: 0.3222, Validation Accuracy: 0.8846
# Epoch 32:
# Train Loss: 0.2562, Train Accuracy: 0.9285
# Validation Loss: 0.3265, Validation Accuracy: 0.8956
# Epoch 33:
# Train Loss: 0.2600, Train Accuracy: 0.9161
# Validation Loss: 0.3096, Validation Accuracy: 0.8901
# Epoch 34:
# Train Loss: 0.2552, Train Accuracy: 0.9188
# Validation Loss: 0.3157, Validation Accuracy: 0.8846
# Epoch 35:
# Train Loss: 0.2580, Train Accuracy: 0.9243
# Validation Loss: 0.2978, Validation Accuracy: 0.8736
# Epoch 36:
# Train Loss: 0.2437, Train Accuracy: 0.9285
# Validation Loss: 0.3044, Validation Accuracy: 0.9011
# Epoch 37:
# Train Loss: 0.2607, Train Accuracy: 0.9161
# Validation Loss: 0.3155, Validation Accuracy: 0.8846
# Epoch 38:
# Train Loss: 0.2297, Train Accuracy: 0.9285
# Validation Loss: 0.2954, Validation Accuracy: 0.8956
# Epoch 39:
# Train Loss: 0.2462, Train Accuracy: 0.9243
# Validation Loss: 0.3041, Validation Accuracy: 0.8901
# Epoch 40:
# Train Loss: 0.2258, Train Accuracy: 0.9409
# Validation Loss: 0.3097, Validation Accuracy: 0.9066
# Epoch 41:
# Train Loss: 0.2289, Train Accuracy: 0.9285
# Validation Loss: 0.3089, Validation Accuracy: 0.8956
# Epoch 42:
# Train Loss: 0.2407, Train Accuracy: 0.9257
# Validation Loss: 0.2817, Validation Accuracy: 0.9121
# Epoch 43:
# Train Loss: 0.2231, Train Accuracy: 0.9340
# Validation Loss: 0.2817, Validation Accuracy: 0.8956
# Epoch 44:
# Train Loss: 0.2340, Train Accuracy: 0.9298
# Validation Loss: 0.2667, Validation Accuracy: 0.9231
# Epoch 45:
# Train Loss: 0.2412, Train Accuracy: 0.9216
# Validation Loss: 0.3024, Validation Accuracy: 0.9011
# Epoch 46:
# Train Loss: 0.2143, Train Accuracy: 0.9381
# Validation Loss: 0.2656, Validation Accuracy: 0.8901
# Epoch 47:
# Train Loss: 0.2268, Train Accuracy: 0.9354
# Validation Loss: 0.2840, Validation Accuracy: 0.9011
# Epoch 48:
# Train Loss: 0.2249, Train Accuracy: 0.9298
# Validation Loss: 0.2919, Validation Accuracy: 0.8791
# Epoch 49:
# Train Loss: 0.2117, Train Accuracy: 0.9354
# Validation Loss: 0.2752, Validation Accuracy: 0.9286
# Epoch 50:
# Train Loss: 0.2277, Train Accuracy: 0.9271
# Validation Loss: 0.2665, Validation Accuracy: 0.9231
# Epoch 51:
# Train Loss: 0.2204, Train Accuracy: 0.9230
# Validation Loss: 0.3092, Validation Accuracy: 0.8791
# Epoch 52:
# Train Loss: 0.2151, Train Accuracy: 0.9326
# Validation Loss: 0.2698, Validation Accuracy: 0.9121
# Epoch 53:
# Train Loss: 0.2218, Train Accuracy: 0.9257
# Validation Loss: 0.2760, Validation Accuracy: 0.9066
# Epoch 54:
# Train Loss: 0.2189, Train Accuracy: 0.9326
# Validation Loss: 0.2496, Validation Accuracy: 0.9176
# Epoch 55:
# Train Loss: 0.2279, Train Accuracy: 0.9285
# Validation Loss: 0.2823, Validation Accuracy: 0.9066
# Epoch 56:
# Train Loss: 0.2026, Train Accuracy: 0.9367
# Validation Loss: 0.2751, Validation Accuracy: 0.8956
# Epoch 57:
# Train Loss: 0.1967, Train Accuracy: 0.9340
# Validation Loss: 0.2815, Validation Accuracy: 0.9066
# Epoch 58:
# Train Loss: 0.2108, Train Accuracy: 0.9298
# Validation Loss: 0.2605, Validation Accuracy: 0.8791
# Early stopping at epoch 59 with validation loss 0.2496
# Results saved for lr: 0.0001, batch: 16, fold: 1, repeat: 1
# Training with learning rate: 0.0001, batch size: 16, fold: 2, repeat: 0
# Epoch 1:
# Train Loss: 0.6411, Train Accuracy: 0.6080
# Validation Loss: 0.6230, Validation Accuracy: 0.6374
# Epoch 2:
# Train Loss: 0.5739, Train Accuracy: 0.6974
# Validation Loss: 0.6084, Validation Accuracy: 0.6319
# Epoch 3:
# Train Loss: 0.5516, Train Accuracy: 0.7139
# Validation Loss: 0.5691, Validation Accuracy: 0.7143
# Epoch 4:
# Train Loss: 0.5252, Train Accuracy: 0.7675
# Validation Loss: 0.5383, Validation Accuracy: 0.7418
# Epoch 5:
# Train Loss: 0.5052, Train Accuracy: 0.7854
# Validation Loss: 0.5115, Validation Accuracy: 0.7418
# Epoch 6:
# Train Loss: 0.4721, Train Accuracy: 0.8157
# Validation Loss: 0.4941, Validation Accuracy: 0.7967
# Epoch 7:
# Train Loss: 0.4580, Train Accuracy: 0.8184
# Validation Loss: 0.4704, Validation Accuracy: 0.8132
# Epoch 8:
# Train Loss: 0.4409, Train Accuracy: 0.8514
# Validation Loss: 0.4578, Validation Accuracy: 0.8077
# Epoch 9:
# Train Loss: 0.4181, Train Accuracy: 0.8624
# Validation Loss: 0.4401, Validation Accuracy: 0.8077
# Epoch 10:
# Train Loss: 0.4143, Train Accuracy: 0.8487
# Validation Loss: 0.4379, Validation Accuracy: 0.8077
# Epoch 11:
# Train Loss: 0.3920, Train Accuracy: 0.8693
# Validation Loss: 0.4059, Validation Accuracy: 0.8681
# Epoch 12:
# Train Loss: 0.3748, Train Accuracy: 0.8803
# Validation Loss: 0.4137, Validation Accuracy: 0.8297
# Epoch 13:
# Train Loss: 0.3768, Train Accuracy: 0.8776
# Validation Loss: 0.4001, Validation Accuracy: 0.8736
# Epoch 14:
# Train Loss: 0.3608, Train Accuracy: 0.8858
# Validation Loss: 0.3598, Validation Accuracy: 0.9121
# Epoch 15:
# Train Loss: 0.3511, Train Accuracy: 0.8817
# Validation Loss: 0.3636, Validation Accuracy: 0.8791
# Epoch 16:
# Train Loss: 0.3525, Train Accuracy: 0.8886
# Validation Loss: 0.3602, Validation Accuracy: 0.9066
# Epoch 17:
# Train Loss: 0.3387, Train Accuracy: 0.8762
# Validation Loss: 0.3604, Validation Accuracy: 0.8736
# Epoch 18:
# Train Loss: 0.3381, Train Accuracy: 0.8913
# Validation Loss: 0.3463, Validation Accuracy: 0.8901
# Epoch 19:
# Train Loss: 0.3297, Train Accuracy: 0.8968
# Validation Loss: 0.3333, Validation Accuracy: 0.9176
# Epoch 20:
# Train Loss: 0.3105, Train Accuracy: 0.9078
# Validation Loss: 0.3245, Validation Accuracy: 0.9121
# Epoch 21:
# Train Loss: 0.3221, Train Accuracy: 0.8872
# Validation Loss: 0.3331, Validation Accuracy: 0.8736
# Epoch 22:
# Train Loss: 0.3044, Train Accuracy: 0.9051
# Validation Loss: 0.3131, Validation Accuracy: 0.8956
# Epoch 23:
# Train Loss: 0.3165, Train Accuracy: 0.8913
# Validation Loss: 0.3355, Validation Accuracy: 0.8901
# Epoch 24:
# Train Loss: 0.2976, Train Accuracy: 0.9037
# Validation Loss: 0.3161, Validation Accuracy: 0.9011
# Epoch 25:
# Train Loss: 0.2912, Train Accuracy: 0.9051
# Validation Loss: 0.3000, Validation Accuracy: 0.9231
# Epoch 26:
# Train Loss: 0.2864, Train Accuracy: 0.9106
# Validation Loss: 0.3017, Validation Accuracy: 0.9231
# Epoch 27:
# Train Loss: 0.2749, Train Accuracy: 0.9161
# Validation Loss: 0.2981, Validation Accuracy: 0.9121
# Epoch 28:
# Train Loss: 0.2686, Train Accuracy: 0.9106
# Validation Loss: 0.2708, Validation Accuracy: 0.9341
# Epoch 29:
# Train Loss: 0.2805, Train Accuracy: 0.9120
# Validation Loss: 0.2925, Validation Accuracy: 0.9231
# Epoch 30:
# Train Loss: 0.2759, Train Accuracy: 0.9120
# Validation Loss: 0.2949, Validation Accuracy: 0.8901
# Epoch 31:
# Train Loss: 0.2890, Train Accuracy: 0.9010
# Validation Loss: 0.2941, Validation Accuracy: 0.8901
# Epoch 32:
# Train Loss: 0.2727, Train Accuracy: 0.9161
# Validation Loss: 0.2849, Validation Accuracy: 0.9231
# Epoch 33:
# Train Loss: 0.2542, Train Accuracy: 0.9257
# Validation Loss: 0.2574, Validation Accuracy: 0.9231
# Epoch 34:
# Train Loss: 0.2567, Train Accuracy: 0.9188
# Validation Loss: 0.2568, Validation Accuracy: 0.9286
# Epoch 35:
# Train Loss: 0.2415, Train Accuracy: 0.9271
# Validation Loss: 0.2591, Validation Accuracy: 0.9341
# Epoch 36:
# Train Loss: 0.2626, Train Accuracy: 0.9161
# Validation Loss: 0.2418, Validation Accuracy: 0.9286
# Epoch 37:
# Train Loss: 0.2379, Train Accuracy: 0.9354
# Validation Loss: 0.2564, Validation Accuracy: 0.9341
# Epoch 38:
# Train Loss: 0.2275, Train Accuracy: 0.9326
# Validation Loss: 0.2393, Validation Accuracy: 0.9231
# Epoch 39:
# Train Loss: 0.2469, Train Accuracy: 0.9216
# Validation Loss: 0.2455, Validation Accuracy: 0.9451
# Epoch 40:
# Train Loss: 0.2335, Train Accuracy: 0.9175
# Validation Loss: 0.2538, Validation Accuracy: 0.9011
# Epoch 41:
# Train Loss: 0.2406, Train Accuracy: 0.9188
# Validation Loss: 0.2429, Validation Accuracy: 0.9451
# Epoch 42:
# Train Loss: 0.2398, Train Accuracy: 0.9257
# Validation Loss: 0.2508, Validation Accuracy: 0.9066
# Epoch 43:
# Train Loss: 0.2300, Train Accuracy: 0.9271
# Validation Loss: 0.2427, Validation Accuracy: 0.9231
# Epoch 44:
# Train Loss: 0.2358, Train Accuracy: 0.9092
# Validation Loss: 0.2481, Validation Accuracy: 0.9341
# Epoch 45:
# Train Loss: 0.2445, Train Accuracy: 0.9120
# Validation Loss: 0.2386, Validation Accuracy: 0.9231
# Epoch 46:
# Train Loss: 0.2245, Train Accuracy: 0.9271
# Validation Loss: 0.2556, Validation Accuracy: 0.9121
# Epoch 47:
# Train Loss: 0.2420, Train Accuracy: 0.9230
# Validation Loss: 0.2433, Validation Accuracy: 0.9341
# Epoch 48:
# Train Loss: 0.2299, Train Accuracy: 0.9326
# Validation Loss: 0.2195, Validation Accuracy: 0.9560
# Epoch 49:
# Train Loss: 0.2292, Train Accuracy: 0.9312
# Validation Loss: 0.2425, Validation Accuracy: 0.9341
# Epoch 50:
# Train Loss: 0.2253, Train Accuracy: 0.9271
# Validation Loss: 0.2314, Validation Accuracy: 0.9231
# Epoch 51:
# Train Loss: 0.2301, Train Accuracy: 0.9175
# Validation Loss: 0.2407, Validation Accuracy: 0.9286
# Epoch 52:
# Train Loss: 0.2161, Train Accuracy: 0.9381
# Validation Loss: 0.2283, Validation Accuracy: 0.9286
# Epoch 53:
# Train Loss: 0.2318, Train Accuracy: 0.9202
# Validation Loss: 0.2140, Validation Accuracy: 0.9341
# Epoch 54:
# Train Loss: 0.2196, Train Accuracy: 0.9202
# Validation Loss: 0.2046, Validation Accuracy: 0.9560
# Epoch 55:
# Train Loss: 0.2230, Train Accuracy: 0.9367
# Validation Loss: 0.2241, Validation Accuracy: 0.9451
# Epoch 56:
# Train Loss: 0.2158, Train Accuracy: 0.9340
# Validation Loss: 0.2088, Validation Accuracy: 0.9451
# Epoch 57:
# Train Loss: 0.2339, Train Accuracy: 0.9175
# Validation Loss: 0.2172, Validation Accuracy: 0.9286
# Epoch 58:
# Train Loss: 0.2208, Train Accuracy: 0.9298
# Validation Loss: 0.2158, Validation Accuracy: 0.9341
# Epoch 59:
# Train Loss: 0.2082, Train Accuracy: 0.9312
# Validation Loss: 0.2122, Validation Accuracy: 0.9286
# Epoch 60:
# Train Loss: 0.2075, Train Accuracy: 0.9243
# Validation Loss: 0.2039, Validation Accuracy: 0.9451
# Epoch 61:
# Train Loss: 0.2138, Train Accuracy: 0.9367
# Validation Loss: 0.2262, Validation Accuracy: 0.9286
# Epoch 62:
# Train Loss: 0.2215, Train Accuracy: 0.9188
# Validation Loss: 0.2125, Validation Accuracy: 0.9396
# Epoch 63:
# Train Loss: 0.1973, Train Accuracy: 0.9312
# Validation Loss: 0.2085, Validation Accuracy: 0.9451
# Epoch 64:
# Train Loss: 0.1968, Train Accuracy: 0.9409
# Validation Loss: 0.1973, Validation Accuracy: 0.9451
# Epoch 65:
# Train Loss: 0.1981, Train Accuracy: 0.9354
# Validation Loss: 0.2074, Validation Accuracy: 0.9341
# Epoch 66:
# Train Loss: 0.2151, Train Accuracy: 0.9285
# Validation Loss: 0.2156, Validation Accuracy: 0.9231
# Epoch 67:
# Train Loss: 0.1827, Train Accuracy: 0.9422
# Validation Loss: 0.2012, Validation Accuracy: 0.9505
# Epoch 68:
# Train Loss: 0.1940, Train Accuracy: 0.9436
# Validation Loss: 0.1980, Validation Accuracy: 0.9286
# Epoch 69:
# Train Loss: 0.1916, Train Accuracy: 0.9312
# Validation Loss: 0.2110, Validation Accuracy: 0.9396
# Early stopping at epoch 70 with validation loss 0.1973
# Results saved for lr: 0.0001, batch: 16, fold: 2, repeat: 1
# Training with learning rate: 0.0001, batch size: 16, fold: 3, repeat: 0
# Epoch 1:
# Train Loss: 0.6944, Train Accuracy: 0.5653
# Validation Loss: 0.6613, Validation Accuracy: 0.6429
# Epoch 2:
# Train Loss: 0.6451, Train Accuracy: 0.6451
# Validation Loss: 0.6124, Validation Accuracy: 0.6758
# Epoch 3:
# Train Loss: 0.6120, Train Accuracy: 0.6644
# Validation Loss: 0.5795, Validation Accuracy: 0.7088
# Epoch 4:
# Train Loss: 0.5735, Train Accuracy: 0.7139
# Validation Loss: 0.5369, Validation Accuracy: 0.7308
# Epoch 5:
# Train Loss: 0.5313, Train Accuracy: 0.7469
# Validation Loss: 0.5095, Validation Accuracy: 0.7692
# Epoch 6:
# Train Loss: 0.5145, Train Accuracy: 0.7758
# Validation Loss: 0.4927, Validation Accuracy: 0.8022
# Epoch 7:
# Train Loss: 0.4842, Train Accuracy: 0.8061
# Validation Loss: 0.4611, Validation Accuracy: 0.8022
# Epoch 8:
# Train Loss: 0.4621, Train Accuracy: 0.8239
# Validation Loss: 0.4561, Validation Accuracy: 0.8187
# Epoch 9:
# Train Loss: 0.4505, Train Accuracy: 0.8088
# Validation Loss: 0.4087, Validation Accuracy: 0.8571
# Epoch 10:
# Train Loss: 0.4432, Train Accuracy: 0.8459
# Validation Loss: 0.4100, Validation Accuracy: 0.8297
# Epoch 11:
# Train Loss: 0.4163, Train Accuracy: 0.8487
# Validation Loss: 0.3907, Validation Accuracy: 0.8901
# Epoch 12:
# Train Loss: 0.4018, Train Accuracy: 0.8693
# Validation Loss: 0.3818, Validation Accuracy: 0.9176
# Epoch 13:
# Train Loss: 0.3861, Train Accuracy: 0.8583
# Validation Loss: 0.3596, Validation Accuracy: 0.9011
# Epoch 14:
# Train Loss: 0.3757, Train Accuracy: 0.8611
# Validation Loss: 0.3495, Validation Accuracy: 0.9011
# Epoch 15:
# Train Loss: 0.3682, Train Accuracy: 0.8941
# Validation Loss: 0.3409, Validation Accuracy: 0.9066
# Epoch 16:
# Train Loss: 0.3636, Train Accuracy: 0.8872
# Validation Loss: 0.3383, Validation Accuracy: 0.9011
# Epoch 17:
# Train Loss: 0.3527, Train Accuracy: 0.8900
# Validation Loss: 0.3229, Validation Accuracy: 0.9176
# Epoch 18:
# Train Loss: 0.3441, Train Accuracy: 0.8927
# Validation Loss: 0.3260, Validation Accuracy: 0.9231
# Epoch 19:
# Train Loss: 0.3313, Train Accuracy: 0.9023
# Validation Loss: 0.3107, Validation Accuracy: 0.8901
# Epoch 20:
# Train Loss: 0.3284, Train Accuracy: 0.9106
# Validation Loss: 0.2888, Validation Accuracy: 0.9396
# Epoch 21:
# Train Loss: 0.3201, Train Accuracy: 0.9120
# Validation Loss: 0.2951, Validation Accuracy: 0.9066
# Epoch 22:
# Train Loss: 0.3173, Train Accuracy: 0.8996
# Validation Loss: 0.3031, Validation Accuracy: 0.9231
# Epoch 23:
# Train Loss: 0.3205, Train Accuracy: 0.9010
# Validation Loss: 0.2923, Validation Accuracy: 0.9066
# Epoch 24:
# Train Loss: 0.3228, Train Accuracy: 0.8927
# Validation Loss: 0.2737, Validation Accuracy: 0.9231
# Epoch 25:
# Train Loss: 0.3002, Train Accuracy: 0.9037
# Validation Loss: 0.2700, Validation Accuracy: 0.9341
# Epoch 26:
# Train Loss: 0.3005, Train Accuracy: 0.9133
# Validation Loss: 0.2677, Validation Accuracy: 0.9341
# Epoch 27:
# Train Loss: 0.2943, Train Accuracy: 0.9120
# Validation Loss: 0.2686, Validation Accuracy: 0.9341
# Epoch 28:
# Train Loss: 0.3022, Train Accuracy: 0.8886
# Validation Loss: 0.2589, Validation Accuracy: 0.9231
# Epoch 29:
# Train Loss: 0.2760, Train Accuracy: 0.9065
# Validation Loss: 0.2623, Validation Accuracy: 0.9341
# Epoch 30:
# Train Loss: 0.2805, Train Accuracy: 0.9133
# Validation Loss: 0.2607, Validation Accuracy: 0.9341
# Epoch 31:
# Train Loss: 0.2663, Train Accuracy: 0.9147
# Validation Loss: 0.2472, Validation Accuracy: 0.9396
# Epoch 32:
# Train Loss: 0.2713, Train Accuracy: 0.9257
# Validation Loss: 0.2419, Validation Accuracy: 0.9451
# Epoch 33:
# Train Loss: 0.2637, Train Accuracy: 0.9243
# Validation Loss: 0.2394, Validation Accuracy: 0.9505
# Epoch 34:
# Train Loss: 0.2654, Train Accuracy: 0.9175
# Validation Loss: 0.2630, Validation Accuracy: 0.9176
# Epoch 35:
# Train Loss: 0.2548, Train Accuracy: 0.9409
# Validation Loss: 0.2275, Validation Accuracy: 0.9341
# Epoch 36:
# Train Loss: 0.2650, Train Accuracy: 0.9092
# Validation Loss: 0.2370, Validation Accuracy: 0.9396
# Epoch 37:
# Train Loss: 0.2501, Train Accuracy: 0.9298
# Validation Loss: 0.2360, Validation Accuracy: 0.9396
# Epoch 38:
# Train Loss: 0.2673, Train Accuracy: 0.9120
# Validation Loss: 0.2269, Validation Accuracy: 0.9396
# Epoch 39:
# Train Loss: 0.2598, Train Accuracy: 0.9051
# Validation Loss: 0.2150, Validation Accuracy: 0.9505
# Epoch 40:
# Train Loss: 0.2436, Train Accuracy: 0.9230
# Validation Loss: 0.2306, Validation Accuracy: 0.9505
# Epoch 41:
# Train Loss: 0.2454, Train Accuracy: 0.9230
# Validation Loss: 0.2113, Validation Accuracy: 0.9451
# Epoch 42:
# Train Loss: 0.2690, Train Accuracy: 0.9120
# Validation Loss: 0.2245, Validation Accuracy: 0.9231
# Epoch 43:
# Train Loss: 0.2426, Train Accuracy: 0.9161
# Validation Loss: 0.2157, Validation Accuracy: 0.9560
# Epoch 44:
# Train Loss: 0.2278, Train Accuracy: 0.9340
# Validation Loss: 0.2116, Validation Accuracy: 0.9451
# Epoch 45:
# Train Loss: 0.2311, Train Accuracy: 0.9285
# Validation Loss: 0.1969, Validation Accuracy: 0.9505
# Epoch 46:
# Train Loss: 0.2451, Train Accuracy: 0.9243
# Validation Loss: 0.2001, Validation Accuracy: 0.9615
# Epoch 47:
# Train Loss: 0.2274, Train Accuracy: 0.9312
# Validation Loss: 0.2092, Validation Accuracy: 0.9615
# Epoch 48:
# Train Loss: 0.2241, Train Accuracy: 0.9312
# Validation Loss: 0.2058, Validation Accuracy: 0.9451
# Epoch 49:
# Train Loss: 0.2388, Train Accuracy: 0.9216
# Validation Loss: 0.1972, Validation Accuracy: 0.9505
# Epoch 50:
# Train Loss: 0.2331, Train Accuracy: 0.9202
# Validation Loss: 0.2147, Validation Accuracy: 0.9231
# Epoch 51:
# Train Loss: 0.2348, Train Accuracy: 0.9106
# Validation Loss: 0.2114, Validation Accuracy: 0.9505
# Epoch 52:
# Train Loss: 0.2203, Train Accuracy: 0.9395
# Validation Loss: 0.1966, Validation Accuracy: 0.9121
# Epoch 53:
# Train Loss: 0.2473, Train Accuracy: 0.9051
# Validation Loss: 0.1916, Validation Accuracy: 0.9396
# Epoch 54:
# Train Loss: 0.2065, Train Accuracy: 0.9409
# Validation Loss: 0.2075, Validation Accuracy: 0.9286
# Epoch 55:
# Train Loss: 0.2167, Train Accuracy: 0.9312
# Validation Loss: 0.2032, Validation Accuracy: 0.9396
# Epoch 56:
# Train Loss: 0.2387, Train Accuracy: 0.9202
# Validation Loss: 0.2014, Validation Accuracy: 0.9396
# Epoch 57:
# Train Loss: 0.2232, Train Accuracy: 0.9257
# Validation Loss: 0.2068, Validation Accuracy: 0.9396
# Epoch 58:
# Train Loss: 0.2191, Train Accuracy: 0.9271
# Validation Loss: 0.1853, Validation Accuracy: 0.9451
# Epoch 59:
# Train Loss: 0.2139, Train Accuracy: 0.9312
# Validation Loss: 0.1910, Validation Accuracy: 0.9560
# Early stopping at epoch 60 with validation loss 0.1853
# Results saved for lr: 0.0001, batch: 16, fold: 3, repeat: 1
# Training with learning rate: 0.0001, batch size: 16, fold: 4, repeat: 0
# Epoch 1:
# Train Loss: 0.6466, Train Accuracy: 0.6209
# Validation Loss: 0.6086, Validation Accuracy: 0.6740
# Epoch 2:
# Train Loss: 0.5868, Train Accuracy: 0.6786
# Validation Loss: 0.5918, Validation Accuracy: 0.7017
# Epoch 3:
# Train Loss: 0.5520, Train Accuracy: 0.7198
# Validation Loss: 0.5466, Validation Accuracy: 0.7293
# Epoch 4:
# Train Loss: 0.5346, Train Accuracy: 0.7390
# Validation Loss: 0.5120, Validation Accuracy: 0.7845
# Epoch 5:
# Train Loss: 0.5128, Train Accuracy: 0.7788
# Validation Loss: 0.5079, Validation Accuracy: 0.7845
# Epoch 6:
# Train Loss: 0.4771, Train Accuracy: 0.8132
# Validation Loss: 0.4644, Validation Accuracy: 0.8232
# Epoch 7:
# Train Loss: 0.4593, Train Accuracy: 0.8434
# Validation Loss: 0.4488, Validation Accuracy: 0.8619
# Epoch 8:
# Train Loss: 0.4350, Train Accuracy: 0.8489
# Validation Loss: 0.4424, Validation Accuracy: 0.8343
# Epoch 9:
# Train Loss: 0.4248, Train Accuracy: 0.8379
# Validation Loss: 0.4167, Validation Accuracy: 0.8674
# Epoch 10:
# Train Loss: 0.3958, Train Accuracy: 0.8709
# Validation Loss: 0.3948, Validation Accuracy: 0.8840
# Epoch 11:
# Train Loss: 0.3984, Train Accuracy: 0.8750
# Validation Loss: 0.3872, Validation Accuracy: 0.8895
# Epoch 12:
# Train Loss: 0.3945, Train Accuracy: 0.8640
# Validation Loss: 0.3667, Validation Accuracy: 0.8674
# Epoch 13:
# Train Loss: 0.3702, Train Accuracy: 0.8887
# Validation Loss: 0.3555, Validation Accuracy: 0.8840
# Epoch 14:
# Train Loss: 0.3565, Train Accuracy: 0.9025
# Validation Loss: 0.3383, Validation Accuracy: 0.9061
# Epoch 15:
# Train Loss: 0.3471, Train Accuracy: 0.9080
# Validation Loss: 0.3388, Validation Accuracy: 0.9061
# Epoch 16:
# Train Loss: 0.3427, Train Accuracy: 0.8956
# Validation Loss: 0.3332, Validation Accuracy: 0.8840
# Epoch 17:
# Train Loss: 0.3420, Train Accuracy: 0.8887
# Validation Loss: 0.3264, Validation Accuracy: 0.9061
# Epoch 18:
# Train Loss: 0.3322, Train Accuracy: 0.8887
# Validation Loss: 0.3036, Validation Accuracy: 0.9116
# Epoch 19:
# Train Loss: 0.3368, Train Accuracy: 0.8777
# Validation Loss: 0.2901, Validation Accuracy: 0.9116
# Epoch 20:
# Train Loss: 0.3144, Train Accuracy: 0.8901
# Validation Loss: 0.3036, Validation Accuracy: 0.9171
# Epoch 21:
# Train Loss: 0.3105, Train Accuracy: 0.8956
# Validation Loss: 0.2951, Validation Accuracy: 0.9116
# Epoch 22:
# Train Loss: 0.3026, Train Accuracy: 0.9025
# Validation Loss: 0.2843, Validation Accuracy: 0.9171
# Epoch 23:
# Train Loss: 0.2968, Train Accuracy: 0.9135
# Validation Loss: 0.2748, Validation Accuracy: 0.9227
# Epoch 24:
# Train Loss: 0.2877, Train Accuracy: 0.9203
# Validation Loss: 0.2900, Validation Accuracy: 0.9337
# Epoch 25:
# Train Loss: 0.2933, Train Accuracy: 0.9052
# Validation Loss: 0.2821, Validation Accuracy: 0.9282
# Epoch 26:
# Train Loss: 0.2926, Train Accuracy: 0.9025
# Validation Loss: 0.2638, Validation Accuracy: 0.9337
# Epoch 27:
# Train Loss: 0.2661, Train Accuracy: 0.9299
# Validation Loss: 0.2821, Validation Accuracy: 0.9227
# Epoch 28:
# Train Loss: 0.2756, Train Accuracy: 0.9176
# Validation Loss: 0.2658, Validation Accuracy: 0.9337
# Epoch 29:
# Train Loss: 0.2773, Train Accuracy: 0.9135
# Validation Loss: 0.2435, Validation Accuracy: 0.9392
# Epoch 30:
# Train Loss: 0.2658, Train Accuracy: 0.9217
# Validation Loss: 0.2629, Validation Accuracy: 0.9171
# Epoch 31:
# Train Loss: 0.2473, Train Accuracy: 0.9299
# Validation Loss: 0.2655, Validation Accuracy: 0.9061
# Epoch 32:
# Train Loss: 0.2661, Train Accuracy: 0.9231
# Validation Loss: 0.2612, Validation Accuracy: 0.9227
# Epoch 33:
# Train Loss: 0.2718, Train Accuracy: 0.9121
# Validation Loss: 0.2525, Validation Accuracy: 0.9116
# Epoch 34:
# Train Loss: 0.2623, Train Accuracy: 0.9203
# Validation Loss: 0.2345, Validation Accuracy: 0.9282
# Epoch 35:
# Train Loss: 0.2672, Train Accuracy: 0.9107
# Validation Loss: 0.2283, Validation Accuracy: 0.9392
# Epoch 36:
# Train Loss: 0.2563, Train Accuracy: 0.9080
# Validation Loss: 0.2493, Validation Accuracy: 0.9282
# Epoch 37:
# Train Loss: 0.2572, Train Accuracy: 0.9176
# Validation Loss: 0.2401, Validation Accuracy: 0.9171
# Epoch 38:
# Train Loss: 0.2524, Train Accuracy: 0.9121
# Validation Loss: 0.2617, Validation Accuracy: 0.8895
# Epoch 39:
# Train Loss: 0.2480, Train Accuracy: 0.9272
# Validation Loss: 0.2283, Validation Accuracy: 0.9392
# Epoch 40:
# Train Loss: 0.2256, Train Accuracy: 0.9258
# Validation Loss: 0.2376, Validation Accuracy: 0.9227
# Epoch 41:
# Train Loss: 0.2395, Train Accuracy: 0.9217
# Validation Loss: 0.2086, Validation Accuracy: 0.9503
# Epoch 42:
# Train Loss: 0.2473, Train Accuracy: 0.9190
# Validation Loss: 0.2190, Validation Accuracy: 0.9282
# Epoch 43:
# Train Loss: 0.2383, Train Accuracy: 0.9313
# Validation Loss: 0.2143, Validation Accuracy: 0.9613
# Epoch 44:
# Train Loss: 0.2324, Train Accuracy: 0.9245
# Validation Loss: 0.2205, Validation Accuracy: 0.9503
# Epoch 45:
# Train Loss: 0.2057, Train Accuracy: 0.9382
# Validation Loss: 0.2126, Validation Accuracy: 0.9337
# Epoch 46:
# Train Loss: 0.2308, Train Accuracy: 0.9299
# Validation Loss: 0.2395, Validation Accuracy: 0.9282
# Epoch 47:
# Train Loss: 0.2222, Train Accuracy: 0.9409
# Validation Loss: 0.2213, Validation Accuracy: 0.9392
# Epoch 48:
# Train Loss: 0.2260, Train Accuracy: 0.9258
# Validation Loss: 0.2152, Validation Accuracy: 0.9227
# Epoch 49:
# Train Loss: 0.2299, Train Accuracy: 0.9135
# Validation Loss: 0.2262, Validation Accuracy: 0.9282
# Epoch 50:
# Train Loss: 0.2243, Train Accuracy: 0.9203
# Validation Loss: 0.1954, Validation Accuracy: 0.9448
# Epoch 51:
# Train Loss: 0.2426, Train Accuracy: 0.9107
# Validation Loss: 0.2078, Validation Accuracy: 0.9448
# Epoch 52:
# Train Loss: 0.2240, Train Accuracy: 0.9286
# Validation Loss: 0.2041, Validation Accuracy: 0.9392
# Epoch 53:
# Train Loss: 0.2111, Train Accuracy: 0.9423
# Validation Loss: 0.2107, Validation Accuracy: 0.9503
# Epoch 54:
# Train Loss: 0.2286, Train Accuracy: 0.9231
# Validation Loss: 0.1803, Validation Accuracy: 0.9613
# Epoch 55:
# Train Loss: 0.2241, Train Accuracy: 0.9203
# Validation Loss: 0.1977, Validation Accuracy: 0.9558
# Epoch 56:
# Train Loss: 0.2155, Train Accuracy: 0.9245
# Validation Loss: 0.2066, Validation Accuracy: 0.9337
# Epoch 57:
# Train Loss: 0.2253, Train Accuracy: 0.9231
# Validation Loss: 0.2085, Validation Accuracy: 0.9227
# Epoch 58:
# Train Loss: 0.2103, Train Accuracy: 0.9272
# Validation Loss: 0.1786, Validation Accuracy: 0.9392
# Epoch 59:
# Train Loss: 0.2173, Train Accuracy: 0.9286
# Validation Loss: 0.2074, Validation Accuracy: 0.9448
# Epoch 60:
# Train Loss: 0.2151, Train Accuracy: 0.9272
# Validation Loss: 0.1958, Validation Accuracy: 0.9337
# Epoch 61:
# Train Loss: 0.2026, Train Accuracy: 0.9396
# Validation Loss: 0.1906, Validation Accuracy: 0.9503
# Early stopping at epoch 62 with validation loss 0.1786
# Results saved for lr: 0.0001, batch: 16, fold: 4, repeat: 1

# %%
test_img_paths = glob(os.path.join(test_path, 'images', '*.png'))
test_img_paths.sort()
test_data_csv = pd.read_csv(test_csv_path)
test_dataset = CustomDataset(test_img_paths, None, test_data_csv, is_train=False, resize_dim=RESIZE_DIM)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
model_path = r'/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/classification_model'
model_paths = glob(os.path.join(model_path, 'best_model_self_written*.pth'))
model_paths.sort()
print(f'Model Paths: {model_paths}')
y_pred = []

for model in model_paths:
    # Instantiate a new model instance (ensure the architecture is the same as during training)
    # Check if the model file corresponds to ResNet18 or CNNclassificationmodel
    model_instance = models.resnet18(pretrained=False)
    model_instance.fc = nn.Sequential(
        nn.Linear(model_instance.fc.in_features, 1)
    )
    
    # Load the model state dictionary
    model_state_dict = torch.load(model)
    model_instance.load_state_dict(model_state_dict)
    
    # Set the model to evaluation mode
    model_instance.eval()
    
    # List to store predictions for the current model
    model_preds = []
    
    # Iterate over the test DataLoader
    with torch.no_grad():
        for data in test_loader:
            images = data['image'].to(DEVICE)
            id = data['id']
            outputs = model_instance(images)
            probs = torch.sigmoid(outputs)
            probs = (probs > 0.5).int()
            model_preds.append((id[0],probs.cpu().item()))
    y_pred.append(list(model_preds))

test_data_df = pd.read_csv(test_csv_path)

y_pred_dict = {}
for model_preds in y_pred:
    for id, pred in model_preds:
        if id not in y_pred_dict:
            y_pred_dict[id] = [pred]
        else:
            y_pred_dict[id].append(pred)

# Perform majority voting
final_predictions = []
for id, preds in y_pred_dict.items():
    # Count the number of 1s and 0s
    count_1 = preds.count(1)
    count_0 = preds.count(0)
    
    # If the count of 1s is greater than the count of 0s, predict 1, else predict 0
    if count_1 > count_0:
        final_predictions.append((id, 1))
    else:
        final_predictions.append((id, 0))

# Convert the final predictions to a DataFrame
submission_df = pd.DataFrame(final_predictions, columns=['id', 'binary_pred'])
# Save the predictions to a CSV file
submission_df.to_csv('submission_class_resnet34.csv', index=False)
# Out:
# Model Paths: ['/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/classification_model/best_model_resnet34_lr_0.0001_batch_16_fold_0_repeat_0.pth', '/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/classification_model/best_model_resnet34_lr_0.0001_batch_16_fold_1_repeat_0.pth', '/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/classification_model/best_model_resnet34_lr_0.0001_batch_16_fold_2_repeat_0.pth', '/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/classification_model/best_model_resnet34_lr_0.0001_batch_16_fold_3_repeat_0.pth', '/home/biomedialab/Desktop/Codes/Assignments/MLDS/Assignment_2/Q2/classification_model/best_model_resnet34_lr_0.0001_batch_16_fold_4_repeat_0.pth']
# /home/biomedialab/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/biomedialab/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
